# %%
# !nvidia-smi
# Out:
# Wed Mar 27 20:19:28 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics==8.0.114
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 595.4/595.4 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 56.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 62.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 81.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import RTDETR

# %%
# !yolo detect train model=rtdetr-l.pt data=/content/drive/MyDrive/car_brand/data.yaml epochs=200 patience=200

# %% [markdown]
# ## Custom Training

# %%
from ultralytics import YOLO
import torch
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# WARNING ⚠️ 'yolo mode=checks' is deprecated. Use 'yolo checks' instead.
# Ultralytics YOLOv8.0.114 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/78.2 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model = YOLO('yolov8n.pt')

# %%
results = model('/content/drive/MyDrive/TEST/test_yolo.jpg',save=True)
# Out:
# image 1/1 /content/drive/MyDrive/TEST/test_yolo.jpg: 448x640 6 persons, 1 bus, 3 handbags, 82.4ms
# Speed: 2.5ms preprocess, 82.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
# %cd /content/drive/MyDrive/car_brand_train_1000
# Out:
# /content/drive/MyDrive/car_brand_train_1000

# %%
# !ls
# Out:
# data  data.yaml  runs  yolov8n.pt

# %%
# %cd /content/drive/MyDrive/car_brand_train_1000

# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=200
# Out:
# /content/drive/MyDrive/car_brand_train_1000
# New https://pypi.org/project/ultralytics/8.1.20 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.114 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename='/content/drive/MyDrive/car_licensePlate_1000/runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/car_brand_train_1000/runs/detect/train3/results.png', width=800)

# %%
Image(filename='/content/drive/MyDrive/car_brand/runs/detect/train11/train_batch0.jpg', width=800)

# %% [markdown]
# ## Validate Custom Model

# %% [markdown]
# ## Inference with Custom Model

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/chathai-pych/runs/detect/train2/weights/best.pt conf=0.1 source='/content/drive/MyDrive/chathai-pych/runs/detect/frame_53.png'

# %%
model_test = YOLO("/content/drive/MyDrive/car_brand/runs/detect/train3/weights/best.pt")

# %%
results = model_test.predict(source="/content/drive/MyDrive/car_brand/runs/detect/test_input",conf=0.1,save=True)
# Out:
# image 1/12 /content/drive/MyDrive/car_brand/runs/detect/test_input/test (1).jpeg: 384x640 1 Honda, 10.1ms
# image 2/12 /content/drive/MyDrive/car_brand/runs/detect/test_input/test (10).jpeg: 384x640 1 BMW, 6.2ms
# image 3/12 /content/drive/MyDrive/car_brand/runs/detect/test_input/test (11).jpeg: 384x640 (no detections), 6.4ms
# image 4/12 /content/drive/MyDrive/car_brand/runs/detect/test_input/test (12).jpeg: 384x640 1 Ford, 6.6ms
# image 5/12 /content/drive/MyDrive/car_brand/runs/detect/test_input/test (2).jpeg: 384x640 1 BYD, 6.4ms
# image 6/12 /content/drive/MyDrive/car_brand/runs/detect/test_input/test (3).jpeg: 384x640 (no detections), 7.3ms
# image 7/12 /content/drive/MyDrive/car_brand/runs/detect/test_input/test (4).jpeg: 384x640 (no detections), 6.5ms
# image 8/12 /content/drive/MyDrive/car_brand/runs/detect/test_input/test (5).jpeg: 384x640 1 Toyota, 6.5ms
# image 9/12 /content/drive/MyDrive/car_brand/runs/detect/test_input/test (6).jpeg: 384x640 1 Honda, 6.3ms
# ...

# %%
# !yolo val model=/content/drive/MyDrive/province_label/runs/detect/train/weights/best.pt data=/content/drive/MyDrive/province_label/data.yaml split=test
# Out:
# 2023-10-25 16:03:44.260869: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-25 16:03:44.260930: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-25 16:03:44.260970: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Ultralytics YOLOv8.0.114 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3017543 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/province_label/data/test/labels.cache... 14 images, 0 backgrounds, 0 corrupt: 100% 14/14 [00:00<?, ?it/s]
# ...

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('runs/detect/predict/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")
